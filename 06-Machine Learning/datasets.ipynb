# %%
import pandas as pd

# %%
import os

for root, dirs, files in os.walk("../datasets"):  
    for filename in files:
        print filename
        print '--'*8
        print pd.read_csv('../datasets/'+filename).head()
        print
# Out:
# steelPlateFaults.csv
# ----------------
#      V1    V2       V3       V4    V5  V6   V7      V8  V9  V10  ...    \
# 0    42    50   270900   270944   267  17   44   24220  76  108  ...
# 1   645   651  2538079  2538108   108  10   30   11397  84  123  ...
# 2   829   835  1553913  1553931    71   8   19    7972  99  125  ...
# 3   853   860   369370   369415   176  13   45   18996  99  126  ...
# 4  1289  1306   498078   498335  2409  60  260  246930  37  126  ...
#
#       V25     V26     V27  V28  V29  V30  V31  V32  V33  Class
# 0  0.8182 -0.2913  0.5822    1    0    0    0    0    0      1
# 1  0.7931 -0.1756  0.2984    1    0    0    0    0    0      1
# 2  0.6667 -0.1228  0.2150    1    0    0    0    0    0      1
# 3  0.8444 -0.1568  0.5212    1    0    0    0    0    0      1
# 4  0.9338 -0.1992  1.0000    1    0    0    0    0    0      1
#
# [5 rows x 34 columns]
#
# monk2.csv
# ----------------
#    class  attr1  attr2  attr3  attr4  attr5  attr6
# ...

# %%
pd.read_csv('../datasets/phoneme.csv').head()
# Out:
#          V1        V2        V3        V4        V5  Class
# 0  0.489927 -0.451528 -1.047990 -0.598693 -0.020418      1
# 1 -0.641265  0.109245  0.292130 -0.916804  0.240223      1
# 2  0.870593 -0.459862  0.578159  0.806634  0.835248      1
# 3 -0.628439 -0.316284  1.934295 -1.427099 -0.136583      1
# 4 -0.596399  0.015938  2.043206 -1.688448 -0.948127      1

# %%
pd.read_csv('../datasets/banklist.csv').head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17     1-Jun-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17     1-Jun-17
# 2  58302                         Whitney Bank    28-Apr-17    23-May-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
pd.read_csv('../datasets/credit.csv').head()
# Out:
#   checking_status  duration                    credit_history  \
# 0            '<0'         6  'critical/other existing credit'
# 1      '0<=X<200'        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3            '<0'        42                   'existing paid'
# 4            '<0'        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'      '>=7'
# 1             radio/tv           5951              '<100'   '1<=X<4'
# 2            education           2096              '<100'   '4<=X<7'
# 3  furniture/equipment           7882              '<100'   '4<=X<7'
# 4            'new car'           4870              '<100'   '1<=X<4'
#
#    installment_commitment       personal_status other_parties  ...   \
# 0                       4         'male single'          none  ...
# ...

# %%
pd.read_csv('../datasets/delta_elevators.csv').head()
# Out:
#    climbRate  Altitude  RollRate  curRoll  diffClb  diffDiffClb     Se
# 0        2.0       -50   -0.0048   -0.001      0.2          0.0 -0.001
# 1        6.5       -40   -0.0010   -0.009      0.2          0.0  0.003
# 2       -5.9       -10   -0.0033   -0.004     -0.1          0.0 -0.001
# 3       -6.2       -30   -0.0022   -0.011      0.1          0.0 -0.002
# 4       -0.2       -40    0.0059   -0.005      0.1          0.0  0.001

# %%
pd.read_csv('../datasets/delta_elevators_class.csv').head()
# Out:
#    climbRate  Altitude  RollRate  curRoll  diffClb  diffDiffClb  Se
# 0        2.0       -50   -0.0048   -0.001      0.2          0.0   0
# 1        6.5       -40   -0.0010   -0.009      0.2          0.0   1
# 2       -5.9       -10   -0.0033   -0.004     -0.1          0.0   0
# 3       -6.2       -30   -0.0022   -0.011      0.1          0.0   0
# 4       -0.2       -40    0.0059   -0.005      0.1          0.0   1

# %%
pd.read_csv('../datasets/diabetes.csv').head()
# Out:
#     age  deficit  c_peptide
# 0   5.2     -8.1        4.8
# 1   8.8    -16.1        4.1
# 2  10.5     -0.9        5.2
# 3  10.6     -7.8        5.5
# 4  10.4    -29.0        5.0

# %%
pd.read_csv('../datasets/monk2.csv').head()
# Out:
#    class  attr1  attr2  attr3  attr4  attr5  attr6
# 0      0      1      1      1      1      2      2
# 1      0      1      1      1      1      4      1
# 2      0      1      1      1      2      1      1
# 3      0      1      1      1      2      1      2
# 4      0      1      1      1      2      2      1

# %%
pd.read_csv('../datasets/pollution.csv').head()
# Out:
#    PREC  JANT  JULT  OVR65  POPN  EDUC  HOUS  DENS  NONW  WWDRK  POOR  HC  \
# 0    36    27    71    8.1  3.34  11.4  81.5  3243   8.8   42.6  11.7  21
# 1    35    23    72   11.1  3.14  11.0  78.8  4281   3.5   50.7  14.4   8
# 2    44    29    74   10.4  3.21   9.8  81.6  4260   0.8   39.4  12.4   6
# 3    47    45    79    6.5  3.41  11.1  77.5  3125  27.1   50.2  20.6  18
# 4    43    35    77    7.6  3.44   9.6  84.6  6441  24.4   43.7  14.3  43
#
#    NOX  SO2  HUMID      MORT
# 0   15   59     59   921.870
# 1   10   39     57   997.875
# 2    6   33     54   962.354
# 3    8   24     56   982.291
# 4   38  206     55  1071.289

# %%
pd.read_csv('../datasets/price.csv').head()
# Out:
#    Area (sqft)  Price ($)
# 0         2000      88600
# 1         1600      71600
# 2         1980      93300
# 3         1840      84300
# 4         1710      80600
