# %% [markdown]
# ### Relational Database :
# * row-based table structure that connects related data elements
# * schema based
#
# #### Uses:
# * airline reservation systems
# * inventory control
# * sales transactions
# * ATM activity
#
# #### Examples:
# * Mysql
# * Postgreaql
# * Hive

# %% [markdown]
# ### Document Database
# * A document-oriented database is a designed for storing, retrieving, and managing document-oriented, or semi structured data.
#
# #### Examples:
# * Mongodb
# * Couchbase
# * Hbase

# %% [markdown]
# ![relational_vs_doc1.png](attachment:relational_vs_doc1.png)

# %% [markdown]
# ### Unstructured Database
# * refers to information that doesn't reside in a traditional row-column database
# * not really a database
# * text and multimedia content
# * e-mail messages
# * word processing documents
