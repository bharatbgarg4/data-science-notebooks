# %% [markdown]
# # Matplotlib Exercises
#
#
# ## Data

# %%
import numpy as np
x = np.arange(0,20)
r = np.linspace(0,10,100)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Draw Line and Scatter plot for following Equations**

# %% [markdown]
# **y=3x^2+6**

# %%
## Line Plot

# %%
## Scatter Plot

# %% [markdown]
# **y=2x^3-4x^2+8**
# and
# **z=2x^3+4x^2+8**
# on same plots

# %%
## Line Plot

# %%
## Scatter Plot

# %% [markdown]
# **tan(r) and cot(r)

# %%
## Line Plot

# %%
## Scatter Plot

# %% [markdown]
# **Draw Histograms for following numpy generator functions and variables**
#
# * arange with range 50

# %% [markdown]
# * 100 random variables with in range -2 to 3 with mean distribution

# %% [markdown]
# * 100 random variables with standard distribution centered at 5, with variance of 3

# %% [markdown]
# * 100 linearly spaced variable in range 1 to 120

# %% [markdown]
# ### Draw Spaced and Stacked Bar Chart between A and B

# %%
A=(np.random.rand(10)*4)+2
B=(np.random.randn(10)*3)+10
