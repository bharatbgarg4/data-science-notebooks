# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../datasets/diabetes.csv')

# %%
data.head()
# Out:
#     age  deficit  c_peptide
# 0   5.2     -8.1        4.8
# 1   8.8    -16.1        4.1
# 2  10.5     -0.9        5.2
# 3  10.6     -7.8        5.5
# 4  10.4    -29.0        5.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 3 columns):
# age          43 non-null float64
# deficit      43 non-null float64
# c_peptide    43 non-null float64
# dtypes: float64(3)
# memory usage: 1.1 KB

# %%
data.describe()
# Out:
#              age    deficit  c_peptide
# count  43.000000  43.000000  43.000000
# mean    9.032558  -8.148837   4.746512
# std     4.022539   7.123080   0.720565
# min     0.900000 -29.000000   3.000000
# 25%     5.500000 -12.700000   4.450000
# 50%    10.400000  -7.800000   4.900000
# 75%    11.850000  -2.000000   5.100000
# max    15.600000  -0.200000   6.600000

# %%
data.plot.line()

# %%
fig, ax = plt.subplots()
data.plot.scatter(x='age',y='deficit',c='c_peptide',cmap='seismic',ax=ax)

# %% [markdown]
# ### Obeservation
#
# * C Peptide value goes down with age and deficit value, although data points are sparse around low values.
# * Concentrated high values around near zero deficit and higher age.

# %%
fig, ax = plt.subplots()
data.plot.hexbin(x='age',y='deficit',gridsize=12,cmap='Oranges',ax=ax)
